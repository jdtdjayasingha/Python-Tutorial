# %%
x = [5,6,7,8]

# %%
y = ['h','e','l','l','o']

# %%
z = [5,3.5,'c','python',True,[1,2,3]]

# %%
print(z[0])
# Out:
# 5

# %%
print(z[1])
# Out:
# 3.5

# %%
print(z[3])
# Out:
# python

# %%
print(z)
# Out:
# [5, 3.5, 'c', 'python', True, [1, 2, 3]]

# %%
x

# %%
print(x)
# Out:
# [5, 6, 7, 8]

# %%
z[1] = 8

# %%
print(z)
# Out:
# [5, 8, 'c', 'python', True, [1, 2, 3]]
