# %%
x = [5,6,7,8]

# %%
y = ['h','e','l','l','o']

# %%
z = [5,3.5,'c','python',True,[1,2,3]]

# %%
print(z[0])
# Out:
# 5

# %%
z[0]
# Out:
# 5

# %%
z[1]
# Out:
# 2.5

# %%
z[3]
# Out:
# 'python'

# %%
z
# Out:
# [5, 2.5, 'c', 'python', True, [1, 2, 3]]

# %%
x
# Out:
# [5, 6, 7, 8]

# %%
z[1] = 8

# %%
z
# Out:
# [5, 2.5, 'c', 'python', True, [1, 2, 3]]

# %%
z[1] = 2.5

# %%
z
# Out:
# [5, 2.5, 'p', 'p', 'c', 'python', True, [1, 2, 3]]

# %%
len(x)
# Out:
# 4

# %%
len(z)
# Out:
# 6

# %%
z.insert(2,'p')

# %%
z
# Out:
# [5, 2.5, 'p', 'c', 'python', True, [1, 2, 3]]
