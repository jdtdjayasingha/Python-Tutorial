# %%
x = [5,6,7,8]

# %%
y = ['h','e','l','l','o']

# %%
z = [5,3.5,'c','python',True,[1,2,3]]

# %%
print(z[0])
# Out:
# 5

# %%
z[0]
# Out:
# 5

# %%
z[1]
# Out:
# 3.5

# %%
z[3]
# Out:
# 'python'

# %%
z
# Out:
# [5, 3.5, 'c', 'python', True, [1, 2, 3]]

# %%
x
# Out:
# [5, 6, 7, 8]

# %%
z[1] = 8

# %%
z
# Out:
# [5, 8, 'c', 'python', True, [1, 2, 3]]

# %%
z[1] = 2.5

# %%
z
# Out:
# [5, 2.5, 'c', 'python', True, [1, 2, 3]]

# %%
len(x)
# Out:
# 4

# %%
len(z)
# Out:
# 6

# %%
z.insert(2,'p')

# %%
z
# Out:
# [5, 2.5, 'p', 'c', 'python', True, [1, 2, 3]]

# %%
z.append(5)

# %%
z
# Out:
# [5, 2.5, 'p', 'c', 'python', True, [1, 2, 3], 5]

# %%
z.remove(2.5)

# %%
z
# Out:
# [5, 'p', 'c', 'python', True, [1, 2, 3], 5]

# %%
z.remove(5)

# %%
z
# Out:
# ['p', 'c', 'python', True, [1, 2, 3], 5]

# %%
z.pop(1)
# Out:
# 'c'

# %%
z
# Out:
# ['p', 'python', True, [1, 2, 3], 5]

# %%
z.pop()
# Out:
# 5

# %%
z
# Out:
# ['p', 'python', True, [1, 2, 3]]

# %%
a = [1,2,3,4,5]
b = [9,8,7,7,6]

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
del a[1]

# %%
a
# Out:
# [1, 3, 4, 5]

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
b
# Out:
# [9, 8, 7, 7, 6]

# %%
b.clear()

# %%
b
# Out:
# []

# %%
m = [8,1,4,9,3]

# %%
m
# Out:
# [8, 1, 4, 9, 3]

# %%
m.sort()

# %%
m
# Out:
# [1, 3, 4, 8, 9]

# %%
m.sort(reverse = True)

# %%
m
# Out:
# [9, 8, 4, 3, 1]

# %%
a,b,c,d = [1,2,3,4]

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
d
# Out:
# 4

# %%
a,b,c = [1,2,3,4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[215], line 1
# ----> 1 a,b,c = [1,2,3,4]
#
# ValueError: too many values to unpack (expected 3)

# %%
a,b,*c = [1,2,3,4]

# %%
c
# Out:
# [3, 4]

# %%
*a,b,c = [1,5,2,3,4]

# %%
a
# Out:
# [1, 5, 2]
